# %% [markdown]
# Assignment 2

# %% [markdown]
# 1. **3 A flows through a 240 V lamp. What is the resistance of the lamp?**
#
#
# ---
#
# V = I R
#
# resistance = 240 ÷ 3 = 80 Ω

# %% [markdown]
# 2. **How to check the resistance of a resistor using the colour coding ?**
#
#
# ---
# ![how-to-read-resistor-color-codes.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 3. **Mention any 5 virtual environments which we can use for Arduino Simulation?**
#
# ---
# Tinkercad Circuits.
#
# Virtual Breadboard & Avatar Hardware.
#
# SimulIDE.
#
# PICSimLab.
#
# Wokwi.
#
# UnoArduSim

# %% [markdown]
# 4. **What is sketch in Arduino??**
#
# ---
# A sketch is the name that Arduino uses for a program. It's the unit of code that is uploaded to and run on an Arduino board.

# %% [markdown]
# 5. **What are the three important parts of Arduino?**
#
#
# ---
# Arduino programming language can be divided in three main parts: functions, values (variables and constants), and structure.
